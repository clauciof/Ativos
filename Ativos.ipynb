# %% [markdown]
# <a href="https://colab.research.google.com/github/clauciof/Ativos/blob/master/Ativos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importando as bibliotecas que sempre são usadas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import datetime
pd.options.display.max_columns = None
pd.options.display.max_rows = 30
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv("https://raw.githubusercontent.com/clauciof/Ativos/master/1min-17-04%20-%201min-17-04.csv")

# %%
df.head()
# Out:
#         datetime  asset    low   high   open  close  volume_a  volume_v  \
# 0  1587129180000  PETR4  15.68  15.75  15.75  15.71    150300    320700
# 1  1587129240000  PETR4  15.56  15.70  15.70  15.60    714400    542000
# 2  1587129300000  PETR4  15.56  15.64  15.60  15.63    562100    268700
# 3  1587129360000  PETR4  15.57  15.68  15.62  15.64    365600    503400
# 4  1587129420000  PETR4  15.64  15.82  15.64  15.79    639000    144800
#
#    volume_i
# 0   2301800
# 1         0
# 2         0
# 3         0
# 4         0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54033 entries, 0 to 54032
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  54033 non-null  int64
#  1   asset     54033 non-null  object
#  2   low       54033 non-null  float64
#  3   high      54033 non-null  float64
#  4   open      54033 non-null  float64
#  5   close     54033 non-null  float64
#  6   volume_a  54033 non-null  int64
#  7   volume_v  54033 non-null  int64
#  8   volume_i  54033 non-null  int64
# dtypes: float64(4), int64(4), object(1)
# memory usage: 3.7+ MB

# %%
df['asset'].value_counts()
# Out:
# PETR4     834
# WDOK20    503
# DOLK20    500
# MRFG3     419
# HGTX3     418
#          ...
# RLOG3     320
# MILS3     315
# LOGG3     311
# TASA4     269
# UNIP6     200
# Name: asset, Length: 137, dtype: int64

# %%
df['asset'].unique()
# Out:
# array(['PETR4', 'ABEV3', 'AZUL4', 'B3SA3', 'BBAS3', 'BBDC3', 'BBDC4',
#        'BBSE3', 'BPAC11', 'BRAP4', 'BRDT3', 'BRFS3', 'BRKM5', 'BRML3',
#        'BTOW3', 'CCRO3', 'CIEL3', 'CMIG4', 'COGN3', 'CRFB3', 'CSAN3',
#        'CSNA3', 'CVCB3', 'CYRE3', 'ECOR3', 'EGIE3', 'ELET3', 'ELET6',
#        'EMBR3', 'ENBR3', 'EQTL3', 'FLRY3', 'GGBR4', 'GNDI3', 'GOAU4',
#        'GOLL4', 'HAPV3', 'HGTX3', 'HYPE3', 'IGTA3', 'IRBR3', 'ITSA4',
#        'ITUB4', 'JBSS3', 'KLBN11', 'LAME4', 'LREN3', 'MGLU3', 'MRFG3',
#        'MRVE3', 'MULT3', 'NTCO3', 'PCAR3', 'PETR3', 'QUAL3', 'RADL3',
#        'RAIL3', 'RENT3', 'SANB11', 'SBSP3', 'SMLS3', 'SULA11', 'SUZB3',
#        'TAEE11', 'TIMP3', 'TOTS3', 'UGPA3', 'USIM5', 'VALE3', 'VIVT4',
#        'VVAR3', 'WEGE3', 'YDUQ3', 'ABCB4', 'ALSO3', 'ALUP11', 'AMAR3',
#        'ARZZ3', 'BEEF3', 'BIDI11', 'BIDI4', 'BKBR3', 'BPAN4', 'BRPR3',
#        'BRSR6', 'CAML3', 'CESP6', 'CNTO3', 'CSMG3', 'DIRR3', 'DTEX3',
# ...

# %%
#formatando 'datetime'
df['datetime'] = df['datetime'].map(lambda x: datetime.datetime.fromtimestamp(x/1000))

# %%
#bradesco
BD = df.loc[df['asset'] == 'BBDC3']
BD.drop(['asset', 'volume_a', 'volume_v', 'volume_i' ], axis=1, inplace=True)

#ambev
AB = df.loc[df['asset'] == 'ABEV3']
AB.drop(['asset', 'volume_a', 'volume_v', 'volume_i' ], axis=1, inplace=True)

#azul
AZ = df.loc[df['asset'] == 'AZUL4']
AZ.drop(['asset', 'volume_a', 'volume_v', 'volume_i' ], axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Create traces
fig = go.Figure()
fig.add_trace(go.Scatter(x=BD['datetime'], y=BD['low'],
                    mode='lines',
                    name='low '))
fig.add_trace(go.Scatter(x=BD['datetime'],  y=BD['high'],
                    mode='lines',
                    name='high'))


#open/close
fig.add_trace(go.Scatter(x=BD['datetime'], y=BD['open'],
                    mode='lines',
                    name='open '))
fig.add_trace(go.Scatter(x=BD['datetime'],  y=BD['close'],
                    mode='lines',
                    name='close'))

fig.update_layout(title='BBDC4')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="be70ec0b-a628-485d-b5c2-53e845ef31ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("be70ec0b-a628-485d-b5c2-53e845ef31ed")) {
#                     Plotly.newPlot(
#                         'be70ec0b-a628-485d-b5c2-53e845ef31ed',
# ...

# %%
fig = go.Figure(data=[go.Candlestick(x=BD['datetime'],
                open=BD['open'], high=BD['high'],
                low=BD['low'], close=BD['close'])
                     ])

fig.update_layout(title='BBDC4 Candlestick',xaxis_rangeslider_visible=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f42a5211-bccb-442f-a56d-314dc4c9bc68" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f42a5211-bccb-442f-a56d-314dc4c9bc68")) {
#                     Plotly.newPlot(
#                         'f42a5211-bccb-442f-a56d-314dc4c9bc68',
# ...

# %%
# Create traces
fig = go.Figure()
fig.add_trace(go.Scatter(x=AB['datetime'], y=AB['low'],
                    mode='lines',
                    name='low '))
fig.add_trace(go.Scatter(x=AB['datetime'],  y=AB['high'],
                    mode='lines',
                    name='high'))

#open/close
fig.add_trace(go.Scatter(x=AB['datetime'], y=AB['open'],
                    mode='lines',
                    name='open '))
fig.add_trace(go.Scatter(x=AB['datetime'],  y=AB['close'],
                    mode='lines',
                    name='close'))

fig.update_layout(title='ABEV3')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="92d0ac5e-a445-427e-8ff1-8d9d6c87b526" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("92d0ac5e-a445-427e-8ff1-8d9d6c87b526")) {
#                     Plotly.newPlot(
#                         '92d0ac5e-a445-427e-8ff1-8d9d6c87b526',
# ...

# %%
fig = go.Figure(data=[go.Candlestick(x=AB['datetime'],
                open=AB['open'], high=AB['high'],
                low=AB['low'], close=AB['close'])
                     ])

fig.update_layout(title='ABEV4 Candlestick',xaxis_rangeslider_visible=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="619dfb33-c21a-4a4e-80ca-b2ec0711d86d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("619dfb33-c21a-4a4e-80ca-b2ec0711d86d")) {
#                     Plotly.newPlot(
#                         '619dfb33-c21a-4a4e-80ca-b2ec0711d86d',
# ...

# %%
# Create traces
fig = go.Figure()
fig.add_trace(go.Scatter(x=AZ['datetime'], y=AZ['low'],
                    mode='lines',
                    name='low '))
fig.add_trace(go.Scatter(x=AZ['datetime'],  y=AZ['high'],
                    mode='lines',
                    name='high'))

#open/close
fig.add_trace(go.Scatter(x=AZ['datetime'], y=AZ['open'],
                    mode='lines',
                    name='open '))
fig.add_trace(go.Scatter(x=AZ['datetime'],  y=AZ['close'],
                    mode='lines',
                    name='close'))

fig.update_layout(title='AZUL4')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2a3afc54-7c95-430e-a7b6-aae7efeab342" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2a3afc54-7c95-430e-a7b6-aae7efeab342")) {
#                     Plotly.newPlot(
#                         '2a3afc54-7c95-430e-a7b6-aae7efeab342',
# ...

# %%
fig = go.Figure(data=[go.Candlestick(x=AZ['datetime'],
                open=AZ['open'], high=AZ['high'],
                low=AZ['low'], close=AZ['close'])])

fig.update_layout(title='AZUL4 Candlestick',xaxis_rangeslider_visible=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="332a196f-f3dd-46d0-9bc8-4abadf7e4173" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("332a196f-f3dd-46d0-9bc8-4abadf7e4173")) {
#                     Plotly.newPlot(
#                         '332a196f-f3dd-46d0-9bc8-4abadf7e4173',
# ...
